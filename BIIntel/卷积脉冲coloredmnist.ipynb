# %%
import os
import time
import argparse
import sys
import datetime

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
from torch.cuda import amp
from torch.utils.tensorboard import SummaryWriter
import torchvision
import numpy as np

from spikingjelly.activation_based import neuron, encoding, functional, surrogate, layer
from ColorMNIST import ColorMNIST
import numpy as np

path_to_mnist = '/workspace/mnist_data/MNIST'

#定义SNN网络结构
class SNN(nn.Module):
    def __init__(self, tau):
        super().__init__()

        self.layer = nn.Sequential(
            # layer.Flatten(),
            # layer.Linear(28 * 28, 10, bias=False),
            layer.Conv2d(3, 128, kernel_size=3, padding=1, bias=False),    #普通卷积层
            layer.BatchNorm2d(128),
            #neuron.LIFNode(tau=tau, surrogate_function=surrogate.ATan()),
            layer.MaxPool2d(4, 4),

            layer.Flatten(),
            layer.Linear(7 * 7 * 128, 10, bias=False),
            #SNN LIF Node
            neuron.LIFNode(tau=tau, surrogate_function=surrogate.ATan()),
            )

    def forward(self, x: torch.Tensor):
        return self.layer(x)

def main():
    '''
    :return: None

    * :ref:`API in English <lif_fc_mnist.main-en>`

    .. _lif_fc_mnist.main-cn:

    使用全连接-LIF的网络结构，进行MNIST识别。\n
    这个函数会初始化网络进行训练，并显示训练过程中在测试集的正确率。

    * :ref:`中文API <lif_fc_mnist.main-cn>`

    .. _lif_fc_mnist.main-en:

    The network with FC-LIF structure for classifying MNIST.\n
    This function initials the network, starts trainingand shows accuracy on test dataset.
    '''
    class parser:
        def __init__(self):
            self.T = 100
            self.device='cuda:0'#cpu'
            self.epochs = 100
            self.b = 64
            self.j=4
            self.data_dir='/workspace/mnist_data'
            self.out_dir='./logs'
            self.resume = None
            self.amp = True#False
            self.opt = 'adam'
            self.lr=1e-3
            self.tau=2.0
    '''        
    parser = argparse.ArgumentParser(description='LIF MNIST Training')
    parser.add_argument('-T', default=100, type=int, help='simulating time-steps')
    parser.add_argument('-device', default='cuda:0', help='device')
    parser.add_argument('-b', default=64, type=int, help='batch size')
    parser.add_argument('-epochs', default=100, type=int, metavar='N',
                        help='number of total epochs to run')
    parser.add_argument('-j', default=4, type=int, metavar='N',
                        help='number of data loading workers (default: 4)')
    parser.add_argument('-data-dir', type=str, help='root dir of MNIST dataset')
    parser.add_argument('-out-dir', type=str, default='./logs', help='root dir for saving logs and checkpoint')
    parser.add_argument('-resume', type=str, help='resume from the checkpoint path')
    parser.add_argument('-amp', action='store_true', help='automatic mixed precision training')
    parser.add_argument('-opt', type=str, choices=['sgd', 'adam'], default='adam', help='use which optimizer. SGD or Adam')
    parser.add_argument('-momentum', default=0.9, type=float, help='momentum for SGD')
    parser.add_argument('-lr', default=1e-3, type=float, help='learning rate')
    parser.add_argument('-tau', default=2.0, type=float, help='parameter tau of LIF neuron')
    '''
    args = parser()
    #args = parser.parse_args()
    #print(args)

    net = SNN(tau=args.tau)

    print(net)

    net.to(args.device)

    train_dataset = ColorMNIST('both', 'train', path_to_mnist, randomcolor=True)
    test_dataset = ColorMNIST('both', 'test', path_to_mnist, randomcolor=True)
    # 初始化数据加载器
    # train_dataset = torchvision.datasets.MNIST(
    #     root=args.data_dir,
    #     train=True,
    #     transform=torchvision.transforms.ToTensor(),
    #     download=True
    # )
    # test_dataset = torchvision.datasets.MNIST(
    #     root=args.data_dir,
    #     train=False,
    #     transform=torchvision.transforms.ToTensor(),
    #     download=True
    # )

    train_data_loader = data.DataLoader(
        dataset=train_dataset,
        batch_size=args.b,
        shuffle=True,
        drop_last=True,
        num_workers=args.j,
        pin_memory=True
    )
    test_data_loader = data.DataLoader(
        dataset=test_dataset,
        batch_size=args.b,
        shuffle=False,
        drop_last=False,
        num_workers=args.j,
        pin_memory=True
    )

    scaler = None
    if args.amp:
        scaler = amp.GradScaler('cuda')

    start_epoch = 0
    max_test_acc = -1

    optimizer = None
    if args.opt == 'sgd':
        optimizer = torch.optim.SGD(net.parameters(), lr=args.lr, momentum=args.momentum)
    elif args.opt == 'adam':
        optimizer = torch.optim.Adam(net.parameters(), lr=args.lr)
    else:
        raise NotImplementedError(args.opt)

    if args.resume:
        checkpoint = torch.load(args.resume, map_location='cpu')
        net.load_state_dict(checkpoint['net'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        start_epoch = checkpoint['epoch'] + 1
        max_test_acc = checkpoint['max_test_acc']
    
    out_dir = os.path.join(args.out_dir, f'T{args.T}_b{args.b}_{args.opt}_lr{args.lr}')

    if args.amp:
        out_dir += '_amp'

    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
        print(f'Mkdir {out_dir}.')

    with open(os.path.join(out_dir, 'args.txt'), 'w', encoding='utf-8') as args_txt:
        args_txt.write(str(args))

    writer = SummaryWriter(out_dir, purge_step=start_epoch)
    with open(os.path.join(out_dir, 'args.txt'), 'w', encoding='utf-8') as args_txt:
        args_txt.write(str(args))
        args_txt.write('\n')
        args_txt.write(' '.join(sys.argv))

    #使用Poisson编码器对输入进行编码
    encoder = encoding.PoissonEncoder()

    for epoch in range(start_epoch, args.epochs):
        start_time = time.time()
        net.train()
        train_loss = 0
        train_acc = 0
        train_samples = 0
        for img, label in train_data_loader:
            optimizer.zero_grad()
            img = img.to(args.device)
            label = label.to(args.device)
            label_onehot = F.one_hot(label, 10).float() #对输出进行one-hot编码

            if scaler is not None:
                with amp.autocast('cuda'): #使用amp混合精度（Cuda)计算可以加速
                    out_fr = 0. 
                    for t in range(args.T): #SNN内部T步时间步长
                        encoded_img = encoder(img)
                        out_fr += net(encoded_img)  #累加输出的脉冲个数
                    out_fr = out_fr / args.T #输出脉冲个数归一化
                    loss = F.mse_loss(out_fr, label_onehot) #最小化SNN预测值和one-hot编码的区别
                scaler.scale(loss).backward() #使用混合精度计算计算loss
                scaler.step(optimizer)        #使用混合精度计算进行optimization
                scaler.update()
            else:   #同上
                out_fr = 0. 
                for t in range(args.T):
                    encoded_img = encoder(img)
                    out_fr += net(encoded_img)
                out_fr = out_fr / args.T
                loss = F.mse_loss(out_fr, label_onehot)
                loss.backward()
                optimizer.step()

            train_samples += label.numel()
            train_loss += loss.item() * label.numel()
            train_acc += (out_fr.argmax(1) == label).float().sum().item()  #计算训练精确度

            functional.reset_net(net) #注意：此步为必要步骤，让LIF node的membrane potential回到0

        train_time = time.time()
        train_speed = train_samples / (train_time - start_time)
        train_loss /= train_samples
        train_acc /= train_samples

        writer.add_scalar('train_loss', train_loss, epoch)
        writer.add_scalar('train_acc', train_acc, epoch)

        net.eval()
        test_loss = 0
        test_acc = 0
        test_samples = 0
        with torch.no_grad():
            for img, label in test_data_loader:  #类似训练步骤计算测试数据集上的性能
                img = img.to(args.device)
                label = label.to(args.device)
                label_onehot = F.one_hot(label, 10).float()
                out_fr = 0.
                for t in range(args.T):
                    encoded_img = encoder(img)
                    out_fr += net(encoded_img)
                out_fr = out_fr / args.T
                loss = F.mse_loss(out_fr, label_onehot)

                test_samples += label.numel()
                test_loss += loss.item() * label.numel()
                test_acc += (out_fr.argmax(1) == label).float().sum().item()
                functional.reset_net(net)
        test_time = time.time()
        test_speed = test_samples / (test_time - train_time)
        test_loss /= test_samples
        test_acc /= test_samples
        writer.add_scalar('test_loss', test_loss, epoch)
        writer.add_scalar('test_acc', test_acc, epoch)

        save_max = False
        if test_acc > max_test_acc:
            max_test_acc = test_acc
            save_max = True

        checkpoint = {
            'net': net.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epoch': epoch,
            'max_test_acc': max_test_acc
        }

        if save_max:
            torch.save(checkpoint, os.path.join(out_dir, 'checkpoint_max.pth'))

        torch.save(checkpoint, os.path.join(out_dir, 'checkpoint_latest.pth'))

        print(args)
        print(out_dir)
        print(f'epoch ={epoch}, train_loss ={train_loss: .4f}, train_acc ={train_acc: .4f}, test_loss ={test_loss: .4f}, test_acc ={test_acc: .4f}, max_test_acc ={max_test_acc: .4f}')
        print(f'train speed ={train_speed: .4f} images/s, test speed ={test_speed: .4f} images/s')
        print(f'escape time = {(datetime.datetime.now() + datetime.timedelta(seconds=(time.time() - start_time) * (args.epochs - epoch))).strftime("%Y-%m-%d %H:%M:%S")}\n')

    # 保存绘图用数据
    net.eval()
    # 注册钩子
    output_layer = net.layer[-1] # 输出层
    output_layer.v_seq = []
    output_layer.s_seq = []
    def save_hook(m, x, y):
        m.v_seq.append(m.v.unsqueeze(0))
        m.s_seq.append(y.unsqueeze(0))

    output_layer.register_forward_hook(save_hook)


    with torch.no_grad():
        img, label = test_dataset[0]
        img = img.to(args.device)
        out_fr = 0.
        for t in range(args.T):
            encoded_img = encoder(img)
            encoded_img = encoded_img.unsqueeze(0)
            print("encoded_img.shape is ",encoded_img.shape)
            out_fr += net(encoded_img)
        out_spikes_counter_frequency = (out_fr / args.T).cpu().numpy()
        print(f'Firing rate: {out_spikes_counter_frequency}')

        output_layer.v_seq = torch.cat(output_layer.v_seq)
        output_layer.s_seq = torch.cat(output_layer.s_seq)
        v_t_array = output_layer.v_seq.cpu().numpy().squeeze()  # v_t_array[i][j]表示神经元i在j时刻的电压值
        np.save("v_t_array.npy",v_t_array)
        s_t_array = output_layer.s_seq.cpu().numpy().squeeze()  # s_t_array[i][j]表示神经元i在j时刻释放的脉冲，为0或1
        np.save("s_t_array.npy",s_t_array)


main()
# Out:
# SNN(
#   (layer): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False, step_mode=s)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True, step_mode=s)
#     (2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False, step_mode=s)
#     (3): Flatten(start_dim=1, end_dim=-1, step_mode=s)
#     (4): Linear(in_features=6272, out_features=10, bias=False)
#     (5): LIFNode(
#       v_threshold=1.0, v_reset=0.0, detach_reset=False, step_mode=s, backend=torch, tau=2.0
#       (surrogate_function): ATan(alpha=2.0, spiking=True)
#     )
#   )
# )
# /tmp/ipykernel_363570/4098871019.py:139: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler()
# /tmp/ipykernel_363570/4098871019.py:193: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(): #使用amp混合精度（Cuda)计算可以加速
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =0, train_loss = 0.1120, train_acc = 0.0986, test_loss = 0.1000, test_acc = 0.0980, max_test_acc = 0.0980
# train speed = 1107.1929 images/s, test speed = 3158.4064 images/s
# escape time = 2024-11-15 06:02:55
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =1, train_loss = 0.1001, train_acc = 0.0988, test_loss = 0.1000, test_acc = 0.0980, max_test_acc = 0.0980
# train speed = 1131.8129 images/s, test speed = 3285.9913 images/s
# escape time = 2024-11-15 06:00:44
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =2, train_loss = 0.1000, train_acc = 0.0989, test_loss = 0.1000, test_acc = 0.0980, max_test_acc = 0.0980
# train speed = 1129.3051 images/s, test speed = 3328.8127 images/s
# escape time = 2024-11-15 06:00:52
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =3, train_loss = 0.1001, train_acc = 0.0987, test_loss = 0.1000, test_acc = 0.0980, max_test_acc = 0.0980
# train speed = 1149.7045 images/s, test speed = 3339.8796 images/s
# escape time = 2024-11-15 05:59:19
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =4, train_loss = 0.0992, train_acc = 0.1037, test_loss = 0.0967, test_acc = 0.1323, max_test_acc = 0.1323
# train speed = 1144.3823 images/s, test speed = 3332.2195 images/s
# escape time = 2024-11-15 05:59:43
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =5, train_loss = 0.0873, train_acc = 0.2394, test_loss = 0.0743, test_acc = 0.4082, max_test_acc = 0.4082
# train speed = 1146.1304 images/s, test speed = 3307.2987 images/s
# escape time = 2024-11-15 05:59:38
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =6, train_loss = 0.0619, train_acc = 0.5440, test_loss = 0.0514, test_acc = 0.6602, max_test_acc = 0.6602
# train speed = 1146.8944 images/s, test speed = 3317.1516 images/s
# escape time = 2024-11-15 05:59:34
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =7, train_loss = 0.0453, train_acc = 0.7262, test_loss = 0.0415, test_acc = 0.7692, max_test_acc = 0.7692
# train speed = 1146.5069 images/s, test speed = 3347.7175 images/s
# escape time = 2024-11-15 05:59:32
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =8, train_loss = 0.0402, train_acc = 0.7845, test_loss = 0.0384, test_acc = 0.8037, max_test_acc = 0.8037
# train speed = 1143.0234 images/s, test speed = 3345.8759 images/s
# escape time = 2024-11-15 05:59:47
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =9, train_loss = 0.0379, train_acc = 0.8062, test_loss = 0.0357, test_acc = 0.8270, max_test_acc = 0.8270
# train speed = 1145.0363 images/s, test speed = 3360.0588 images/s
# escape time = 2024-11-15 05:59:38
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =10, train_loss = 0.0362, train_acc = 0.8232, test_loss = 0.0354, test_acc = 0.8280, max_test_acc = 0.8280
# train speed = 1144.8548 images/s, test speed = 3340.2709 images/s
# escape time = 2024-11-15 05:59:40
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =11, train_loss = 0.0353, train_acc = 0.8337, test_loss = 0.0348, test_acc = 0.8358, max_test_acc = 0.8358
# train speed = 1146.7826 images/s, test speed = 3337.2921 images/s
# escape time = 2024-11-15 05:59:33
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =12, train_loss = 0.0345, train_acc = 0.8410, test_loss = 0.0334, test_acc = 0.8440, max_test_acc = 0.8440
# train speed = 1145.2931 images/s, test speed = 3326.6290 images/s
# escape time = 2024-11-15 05:59:39
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =13, train_loss = 0.0337, train_acc = 0.8471, test_loss = 0.0322, test_acc = 0.8664, max_test_acc = 0.8664
# train speed = 1145.2726 images/s, test speed = 3304.5901 images/s
# escape time = 2024-11-15 05:59:41
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =14, train_loss = 0.0334, train_acc = 0.8492, test_loss = 0.0323, test_acc = 0.8598, max_test_acc = 0.8664
# train speed = 1144.1358 images/s, test speed = 3297.2237 images/s
# escape time = 2024-11-15 05:59:46
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =15, train_loss = 0.0330, train_acc = 0.8530, test_loss = 0.0320, test_acc = 0.8647, max_test_acc = 0.8664
# train speed = 1146.3768 images/s, test speed = 3336.0018 images/s
# escape time = 2024-11-15 05:59:34
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =16, train_loss = 0.0325, train_acc = 0.8571, test_loss = 0.0319, test_acc = 0.8635, max_test_acc = 0.8664
# train speed = 1144.3135 images/s, test speed = 3343.8478 images/s
# escape time = 2024-11-15 05:59:42
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =17, train_loss = 0.0323, train_acc = 0.8577, test_loss = 0.0317, test_acc = 0.8597, max_test_acc = 0.8664
# train speed = 1145.4051 images/s, test speed = 3333.7278 images/s
# escape time = 2024-11-15 05:59:38
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =18, train_loss = 0.0322, train_acc = 0.8599, test_loss = 0.0307, test_acc = 0.8707, max_test_acc = 0.8707
# train speed = 1191.0337 images/s, test speed = 3977.3141 images/s
# escape time = 2024-11-15 05:56:12
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =19, train_loss = 0.0316, train_acc = 0.8641, test_loss = 0.0311, test_acc = 0.8700, max_test_acc = 0.8707
# train speed = 1236.7117 images/s, test speed = 3951.8654 images/s
# escape time = 2024-11-15 05:53:40
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =20, train_loss = 0.0315, train_acc = 0.8645, test_loss = 0.0311, test_acc = 0.8644, max_test_acc = 0.8707
# train speed = 1229.5484 images/s, test speed = 3947.9228 images/s
# escape time = 2024-11-15 05:54:04
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =21, train_loss = 0.0314, train_acc = 0.8661, test_loss = 0.0306, test_acc = 0.8740, max_test_acc = 0.8740
# train speed = 1231.9680 images/s, test speed = 3973.9399 images/s
# escape time = 2024-11-15 05:53:55
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =22, train_loss = 0.0313, train_acc = 0.8666, test_loss = 0.0305, test_acc = 0.8719, max_test_acc = 0.8740
# train speed = 1234.3460 images/s, test speed = 3964.7261 images/s
# escape time = 2024-11-15 05:53:48
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =23, train_loss = 0.0309, train_acc = 0.8696, test_loss = 0.0297, test_acc = 0.8802, max_test_acc = 0.8802
# train speed = 1232.0968 images/s, test speed = 3959.4093 images/s
# escape time = 2024-11-15 05:53:55
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =24, train_loss = 0.0310, train_acc = 0.8664, test_loss = 0.0303, test_acc = 0.8683, max_test_acc = 0.8802
# train speed = 1237.1980 images/s, test speed = 3957.7687 images/s
# escape time = 2024-11-15 05:53:39
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =25, train_loss = 0.0308, train_acc = 0.8704, test_loss = 0.0300, test_acc = 0.8819, max_test_acc = 0.8819
# train speed = 1233.5023 images/s, test speed = 3959.9977 images/s
# escape time = 2024-11-15 05:53:50
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =26, train_loss = 0.0306, train_acc = 0.8714, test_loss = 0.0301, test_acc = 0.8677, max_test_acc = 0.8819
# train speed = 1233.1966 images/s, test speed = 3972.3174 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =27, train_loss = 0.0308, train_acc = 0.8714, test_loss = 0.0301, test_acc = 0.8765, max_test_acc = 0.8819
# train speed = 1233.7256 images/s, test speed = 3953.4268 images/s
# escape time = 2024-11-15 05:53:50
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =28, train_loss = 0.0304, train_acc = 0.8726, test_loss = 0.0299, test_acc = 0.8796, max_test_acc = 0.8819
# train speed = 1234.2978 images/s, test speed = 3968.4027 images/s
# escape time = 2024-11-15 05:53:48
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =29, train_loss = 0.0303, train_acc = 0.8752, test_loss = 0.0303, test_acc = 0.8714, max_test_acc = 0.8819
# train speed = 1233.2296 images/s, test speed = 3961.1989 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =30, train_loss = 0.0302, train_acc = 0.8749, test_loss = 0.0297, test_acc = 0.8785, max_test_acc = 0.8819
# train speed = 1232.3333 images/s, test speed = 3957.0739 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =31, train_loss = 0.0302, train_acc = 0.8743, test_loss = 0.0295, test_acc = 0.8758, max_test_acc = 0.8819
# train speed = 1234.3882 images/s, test speed = 3967.2800 images/s
# escape time = 2024-11-15 05:53:48
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =32, train_loss = 0.0300, train_acc = 0.8765, test_loss = 0.0294, test_acc = 0.8795, max_test_acc = 0.8819
# train speed = 1230.7187 images/s, test speed = 3968.3148 images/s
# escape time = 2024-11-15 05:53:58
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =33, train_loss = 0.0299, train_acc = 0.8770, test_loss = 0.0299, test_acc = 0.8771, max_test_acc = 0.8819
# train speed = 1230.8481 images/s, test speed = 3963.2501 images/s
# escape time = 2024-11-15 05:53:57
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =34, train_loss = 0.0299, train_acc = 0.8774, test_loss = 0.0290, test_acc = 0.8909, max_test_acc = 0.8909
# train speed = 1235.0608 images/s, test speed = 3966.8624 images/s
# escape time = 2024-11-15 05:53:46
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =35, train_loss = 0.0300, train_acc = 0.8761, test_loss = 0.0292, test_acc = 0.8814, max_test_acc = 0.8909
# train speed = 1233.0448 images/s, test speed = 3967.6519 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =36, train_loss = 0.0298, train_acc = 0.8788, test_loss = 0.0287, test_acc = 0.8862, max_test_acc = 0.8909
# train speed = 1236.7204 images/s, test speed = 3970.5211 images/s
# escape time = 2024-11-15 05:53:42
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =37, train_loss = 0.0297, train_acc = 0.8766, test_loss = 0.0297, test_acc = 0.8861, max_test_acc = 0.8909
# train speed = 1231.2542 images/s, test speed = 3960.4434 images/s
# escape time = 2024-11-15 05:53:56
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =38, train_loss = 0.0295, train_acc = 0.8801, test_loss = 0.0289, test_acc = 0.8895, max_test_acc = 0.8909
# train speed = 1230.1446 images/s, test speed = 3967.0034 images/s
# escape time = 2024-11-15 05:53:59
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =39, train_loss = 0.0295, train_acc = 0.8819, test_loss = 0.0286, test_acc = 0.8874, max_test_acc = 0.8909
# train speed = 1232.2645 images/s, test speed = 3963.7010 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =40, train_loss = 0.0295, train_acc = 0.8804, test_loss = 0.0294, test_acc = 0.8740, max_test_acc = 0.8909
# train speed = 1233.5316 images/s, test speed = 3963.9535 images/s
# escape time = 2024-11-15 05:53:50
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =41, train_loss = 0.0294, train_acc = 0.8807, test_loss = 0.0289, test_acc = 0.8791, max_test_acc = 0.8909
# train speed = 1232.6580 images/s, test speed = 3973.9711 images/s
# escape time = 2024-11-15 05:53:52
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =42, train_loss = 0.0295, train_acc = 0.8795, test_loss = 0.0287, test_acc = 0.8866, max_test_acc = 0.8909
# train speed = 1232.7778 images/s, test speed = 3942.4285 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =43, train_loss = 0.0295, train_acc = 0.8812, test_loss = 0.0288, test_acc = 0.8863, max_test_acc = 0.8909
# train speed = 1233.3353 images/s, test speed = 3959.5625 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =44, train_loss = 0.0293, train_acc = 0.8810, test_loss = 0.0286, test_acc = 0.8871, max_test_acc = 0.8909
# train speed = 1233.8295 images/s, test speed = 3970.9191 images/s
# escape time = 2024-11-15 05:53:50
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =45, train_loss = 0.0292, train_acc = 0.8843, test_loss = 0.0290, test_acc = 0.8833, max_test_acc = 0.8909
# train speed = 1229.9797 images/s, test speed = 3970.4606 images/s
# escape time = 2024-11-15 05:53:58
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =46, train_loss = 0.0293, train_acc = 0.8806, test_loss = 0.0291, test_acc = 0.8815, max_test_acc = 0.8909
# train speed = 1230.4173 images/s, test speed = 3969.7864 images/s
# escape time = 2024-11-15 05:53:57
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =47, train_loss = 0.0291, train_acc = 0.8833, test_loss = 0.0284, test_acc = 0.8891, max_test_acc = 0.8909
# train speed = 1231.6749 images/s, test speed = 3970.3880 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =48, train_loss = 0.0291, train_acc = 0.8838, test_loss = 0.0287, test_acc = 0.8900, max_test_acc = 0.8909
# train speed = 1231.9770 images/s, test speed = 3971.8649 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =49, train_loss = 0.0291, train_acc = 0.8827, test_loss = 0.0285, test_acc = 0.8820, max_test_acc = 0.8909
# train speed = 1232.1369 images/s, test speed = 3971.0161 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =50, train_loss = 0.0289, train_acc = 0.8839, test_loss = 0.0289, test_acc = 0.8874, max_test_acc = 0.8909
# train speed = 1231.7820 images/s, test speed = 3970.0374 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =51, train_loss = 0.0288, train_acc = 0.8843, test_loss = 0.0288, test_acc = 0.8771, max_test_acc = 0.8909
# train speed = 1227.0482 images/s, test speed = 3970.2369 images/s
# escape time = 2024-11-15 05:54:04
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =52, train_loss = 0.0289, train_acc = 0.8842, test_loss = 0.0293, test_acc = 0.8772, max_test_acc = 0.8909
# train speed = 1236.9854 images/s, test speed = 3960.1364 images/s
# escape time = 2024-11-15 05:53:45
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =53, train_loss = 0.0290, train_acc = 0.8839, test_loss = 0.0287, test_acc = 0.8885, max_test_acc = 0.8909
# train speed = 1233.6173 images/s, test speed = 3959.7139 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =54, train_loss = 0.0289, train_acc = 0.8848, test_loss = 0.0284, test_acc = 0.8849, max_test_acc = 0.8909
# train speed = 1232.1393 images/s, test speed = 3956.3580 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =55, train_loss = 0.0288, train_acc = 0.8864, test_loss = 0.0287, test_acc = 0.8826, max_test_acc = 0.8909
# train speed = 1232.2071 images/s, test speed = 3958.4852 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =56, train_loss = 0.0288, train_acc = 0.8851, test_loss = 0.0285, test_acc = 0.8845, max_test_acc = 0.8909
# train speed = 1236.5385 images/s, test speed = 3959.2373 images/s
# escape time = 2024-11-15 05:53:46
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =57, train_loss = 0.0287, train_acc = 0.8854, test_loss = 0.0281, test_acc = 0.8902, max_test_acc = 0.8909
# train speed = 1232.6659 images/s, test speed = 3969.2078 images/s
# escape time = 2024-11-15 05:53:52
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =58, train_loss = 0.0287, train_acc = 0.8868, test_loss = 0.0289, test_acc = 0.8816, max_test_acc = 0.8909
# train speed = 1233.9300 images/s, test speed = 3955.9908 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =59, train_loss = 0.0287, train_acc = 0.8855, test_loss = 0.0283, test_acc = 0.8875, max_test_acc = 0.8909
# train speed = 1233.0822 images/s, test speed = 3969.3694 images/s
# escape time = 2024-11-15 05:53:52
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =60, train_loss = 0.0286, train_acc = 0.8868, test_loss = 0.0282, test_acc = 0.8862, max_test_acc = 0.8909
# train speed = 1233.9146 images/s, test speed = 3964.9930 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =61, train_loss = 0.0287, train_acc = 0.8860, test_loss = 0.0285, test_acc = 0.8930, max_test_acc = 0.8930
# train speed = 1229.0950 images/s, test speed = 3962.0532 images/s
# escape time = 2024-11-15 05:53:58
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =62, train_loss = 0.0285, train_acc = 0.8863, test_loss = 0.0282, test_acc = 0.8886, max_test_acc = 0.8930
# train speed = 1233.2935 images/s, test speed = 3943.5076 images/s
# escape time = 2024-11-15 05:53:52
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =63, train_loss = 0.0286, train_acc = 0.8862, test_loss = 0.0285, test_acc = 0.8858, max_test_acc = 0.8930
# train speed = 1234.3189 images/s, test speed = 3963.9659 images/s
# escape time = 2024-11-15 05:53:50
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =64, train_loss = 0.0285, train_acc = 0.8878, test_loss = 0.0281, test_acc = 0.8870, max_test_acc = 0.8930
# train speed = 1235.8159 images/s, test speed = 3961.3983 images/s
# escape time = 2024-11-15 05:53:48
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =65, train_loss = 0.0284, train_acc = 0.8873, test_loss = 0.0282, test_acc = 0.8957, max_test_acc = 0.8957
# train speed = 1230.7433 images/s, test speed = 3954.6256 images/s
# escape time = 2024-11-15 05:53:55
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =66, train_loss = 0.0287, train_acc = 0.8866, test_loss = 0.0279, test_acc = 0.8832, max_test_acc = 0.8957
# train speed = 1227.9258 images/s, test speed = 3965.2614 images/s
# escape time = 2024-11-15 05:53:59
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =67, train_loss = 0.0285, train_acc = 0.8897, test_loss = 0.0284, test_acc = 0.8866, max_test_acc = 0.8957
# train speed = 1230.6907 images/s, test speed = 3965.0766 images/s
# escape time = 2024-11-15 05:53:55
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =68, train_loss = 0.0285, train_acc = 0.8885, test_loss = 0.0281, test_acc = 0.8970, max_test_acc = 0.8970
# train speed = 1232.1817 images/s, test speed = 3964.5702 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =69, train_loss = 0.0282, train_acc = 0.8911, test_loss = 0.0280, test_acc = 0.8922, max_test_acc = 0.8970
# train speed = 1229.9656 images/s, test speed = 3959.6851 images/s
# escape time = 2024-11-15 05:53:56
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =70, train_loss = 0.0284, train_acc = 0.8881, test_loss = 0.0279, test_acc = 0.8931, max_test_acc = 0.8970
# train speed = 1232.0712 images/s, test speed = 3945.2896 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =71, train_loss = 0.0284, train_acc = 0.8899, test_loss = 0.0272, test_acc = 0.8980, max_test_acc = 0.8980
# train speed = 1233.9251 images/s, test speed = 3968.0948 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =72, train_loss = 0.0284, train_acc = 0.8893, test_loss = 0.0273, test_acc = 0.8951, max_test_acc = 0.8980
# train speed = 1231.1148 images/s, test speed = 3958.7101 images/s
# escape time = 2024-11-15 05:53:55
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =73, train_loss = 0.0285, train_acc = 0.8883, test_loss = 0.0278, test_acc = 0.8904, max_test_acc = 0.8980
# train speed = 1234.6405 images/s, test speed = 3956.7976 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =74, train_loss = 0.0282, train_acc = 0.8891, test_loss = 0.0278, test_acc = 0.8944, max_test_acc = 0.8980
# train speed = 1232.4695 images/s, test speed = 3956.2214 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =75, train_loss = 0.0283, train_acc = 0.8890, test_loss = 0.0278, test_acc = 0.8957, max_test_acc = 0.8980
# train speed = 1232.3322 images/s, test speed = 3966.7461 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =76, train_loss = 0.0283, train_acc = 0.8909, test_loss = 0.0275, test_acc = 0.9007, max_test_acc = 0.9007
# train speed = 1234.0009 images/s, test speed = 3957.7695 images/s
# escape time = 2024-11-15 05:53:52
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =77, train_loss = 0.0282, train_acc = 0.8913, test_loss = 0.0279, test_acc = 0.8908, max_test_acc = 0.9007
# train speed = 1234.1597 images/s, test speed = 3961.4118 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =78, train_loss = 0.0281, train_acc = 0.8904, test_loss = 0.0278, test_acc = 0.8958, max_test_acc = 0.9007
# train speed = 1231.6043 images/s, test speed = 3959.2347 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =79, train_loss = 0.0282, train_acc = 0.8902, test_loss = 0.0279, test_acc = 0.8885, max_test_acc = 0.9007
# train speed = 1231.5498 images/s, test speed = 3967.4920 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =80, train_loss = 0.0283, train_acc = 0.8905, test_loss = 0.0273, test_acc = 0.9020, max_test_acc = 0.9020
# train speed = 1230.2026 images/s, test speed = 3963.8580 images/s
# escape time = 2024-11-15 05:53:55
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =81, train_loss = 0.0282, train_acc = 0.8904, test_loss = 0.0278, test_acc = 0.8923, max_test_acc = 0.9020
# train speed = 1234.5709 images/s, test speed = 3969.8206 images/s
# escape time = 2024-11-15 05:53:51
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =82, train_loss = 0.0283, train_acc = 0.8903, test_loss = 0.0281, test_acc = 0.8903, max_test_acc = 0.9020
# train speed = 1232.4308 images/s, test speed = 3965.2415 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =83, train_loss = 0.0281, train_acc = 0.8927, test_loss = 0.0279, test_acc = 0.8959, max_test_acc = 0.9020
# train speed = 1230.4738 images/s, test speed = 3961.2741 images/s
# escape time = 2024-11-15 05:53:55
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =84, train_loss = 0.0278, train_acc = 0.8932, test_loss = 0.0274, test_acc = 0.9017, max_test_acc = 0.9020
# train speed = 1231.3910 images/s, test speed = 3962.7446 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =85, train_loss = 0.0280, train_acc = 0.8915, test_loss = 0.0275, test_acc = 0.8989, max_test_acc = 0.9020
# train speed = 1234.0363 images/s, test speed = 3967.0507 images/s
# escape time = 2024-11-15 05:53:52
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =86, train_loss = 0.0281, train_acc = 0.8924, test_loss = 0.0280, test_acc = 0.8831, max_test_acc = 0.9020
# train speed = 1231.1547 images/s, test speed = 3965.5924 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =87, train_loss = 0.0282, train_acc = 0.8895, test_loss = 0.0272, test_acc = 0.8983, max_test_acc = 0.9020
# train speed = 1234.4406 images/s, test speed = 3965.3071 images/s
# escape time = 2024-11-15 05:53:52
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =88, train_loss = 0.0280, train_acc = 0.8897, test_loss = 0.0274, test_acc = 0.8961, max_test_acc = 0.9020
# train speed = 1231.2695 images/s, test speed = 3968.2273 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =89, train_loss = 0.0280, train_acc = 0.8908, test_loss = 0.0275, test_acc = 0.8939, max_test_acc = 0.9020
# train speed = 1233.5598 images/s, test speed = 3971.7043 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =90, train_loss = 0.0278, train_acc = 0.8932, test_loss = 0.0274, test_acc = 0.9021, max_test_acc = 0.9021
# train speed = 1228.9725 images/s, test speed = 3967.9540 images/s
# escape time = 2024-11-15 05:53:55
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =91, train_loss = 0.0280, train_acc = 0.8915, test_loss = 0.0273, test_acc = 0.8963, max_test_acc = 0.9021
# train speed = 1232.0619 images/s, test speed = 3966.8939 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =92, train_loss = 0.0279, train_acc = 0.8929, test_loss = 0.0273, test_acc = 0.8992, max_test_acc = 0.9021
# train speed = 1229.7141 images/s, test speed = 3956.9548 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =93, train_loss = 0.0279, train_acc = 0.8920, test_loss = 0.0276, test_acc = 0.8973, max_test_acc = 0.9021
# train speed = 1232.1762 images/s, test speed = 3968.2746 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =94, train_loss = 0.0280, train_acc = 0.8919, test_loss = 0.0273, test_acc = 0.9021, max_test_acc = 0.9021
# train speed = 1231.4474 images/s, test speed = 3961.0646 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =95, train_loss = 0.0279, train_acc = 0.8927, test_loss = 0.0268, test_acc = 0.9007, max_test_acc = 0.9021
# train speed = 1229.1070 images/s, test speed = 3960.0246 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =96, train_loss = 0.0278, train_acc = 0.8934, test_loss = 0.0270, test_acc = 0.9030, max_test_acc = 0.9030
# train speed = 1232.0137 images/s, test speed = 3954.2453 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =97, train_loss = 0.0279, train_acc = 0.8922, test_loss = 0.0274, test_acc = 0.8995, max_test_acc = 0.9030
# train speed = 1233.7888 images/s, test speed = 3962.0757 images/s
# escape time = 2024-11-15 05:53:53
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =98, train_loss = 0.0280, train_acc = 0.8902, test_loss = 0.0274, test_acc = 0.8915, max_test_acc = 0.9030
# train speed = 1230.9862 images/s, test speed = 3960.8050 images/s
# escape time = 2024-11-15 05:53:54
#
# <__main__.main.<locals>.parser object at 0x7efd4af27c10>
# ./logs/T100_b64_adam_lr0.001_amp
# epoch =99, train_loss = 0.0278, train_acc = 0.8951, test_loss = 0.0271, test_acc = 0.8999, max_test_acc = 0.9030
# train speed = 1230.6774 images/s, test speed = 3964.4159 images/s
# escape time = 2024-11-15 05:53:54
#
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# encoded_img.shape is  torch.Size([1, 3, 28, 28])
# Firing rate: [[0.   0.16 0.01 0.04 0.11 0.04 0.06 0.74 0.05 0.03]]
